# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from time import sleep
import random


count = 0
list_data = ["2022-2023","2021-2022","2020-2021","2019-2020"]

country = {
    "Bundes_liga":19,
    "liga_1":18,
    "Primera_liga":16,
    "Premier_liga":12,
    "Seria_A_liga":15
}

headers = [
    {'User-Agent': "Mozilla/5.0 (Windows NT 6.3; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0"},
    {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; rv:109.0) Gecko/20100101 Firefox/114.0'},
    {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36"},
    {'User-Agent': "Mozilla/5.0 (Windows NT 10.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36"},
    {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36"}
    ]
proxies = [
    {'https':'http://QJ0UDV:jyXWSQ@213.166.74.197:9253'},
    {'https':'http://QJ0UDV:jyXWSQ@213.166.74.14:9758'},
    {'https':'http://QJ0UDV:jyXWSQ@213.166.75.244:9096'},
    {'https':'http://QJ0UDV:jyXWSQ@185.191.142.68:9545'},
    {'https':'http://QJ0UDV:jyXWSQ@185.184.78.99:9504'}
    ]
    
def list_math_n10(liga,list_data,headers,proxy,):
    count_proxy = 0
    count = 0
    country = {
    "Bundes_lige":17,
    "liga_1":18,
    "Primera_liga":16,
    "Premier_liga":12,
    "Seria_A_liga":15
    }
    
    list_time_1 = [9,12,14,10,11,16,13,8,15,12]        
    list_time_2 = [12,15,8,13,16,11,10,14,12,9]     
    cikle = [[0,0],[0,1],[0,2],[0,3],[0,4],[1,0],[1,1],[1,2],[1,3],[1,4],[2,0],[2,1],[2,2],[2,3],[2,4],[3,0],[3,1],[3,2],[3,3],[3,4],[4,0],[4,1],[4,2],[4,3],[4,4]]
    random.shuffle(cikle)
    for i in list_data:     
        print(i)
        
        data_list = list()
        url_1 = f"https://soccer365.ru/competitions/{country[liga]}/{i}/results/"
        
        try:
            response_1 = requests.get(url_1,headers=headers[cikle[count_proxy][0]],proxies=proxy[cikle[count_proxy][1]])
        except ConnectionRefusedError:
            response_1 = requests.get(url_1,headers=headers[cikle[count_proxy][0]],proxies=proxy[cikle[count_proxy][1]])
            print(f"ProxyError")
        count_proxy +=1 
        if count_proxy == 25 :
            count_proxy = 0
            
        # тело цикла
        soup_1 = BeautifulSoup(response_1.text,'lxml')
        set1 = list()
        
        coeficent_all = soup_1.find_all('a', class_="game_link")
        for j in coeficent_all:
            set1.append(j.get("dt-id"))
        print(len(set1))
        for k in set1:
            
            url_1 = f"https://soccer365.ru/games/{k}/"
        
            url_2 = f"https://soccer365.ru/games/{k}/&tab=form_teams"
            counter = count%10
            if counter == 9:
                print(k)
        
            count += 1
            
            count_proxy +=1 
            if count_proxy == 25 :
                count_proxy = 0
            try:
                response_1 = requests.get(url_1,headers=headers[cikle[count_proxy][0]],proxies=proxies[cikle[count_proxy][1]])
                sleep(list_time_1[counter])
            except ConnectionRefusedError:
                response_1 = requests.get(url_1,headers=headers[cikle[count_proxy][0]],proxies=proxies[cikle[count_proxy][1]])
                sleep(list_time_1[counter])
                print(f"ProxyError в {k}")
            count_proxy +=1 
            if count_proxy == 25 :
                count_proxy = 0
            try:
                response_2 = requests.get(url_2,headers=headers[cikle[count_proxy][0]],proxies=proxies[cikle[count_proxy][1]])
                sleep(list_time_2[counter])
            except ConnectionRefusedError:
                response_2 = requests.get(url_2,headers=headers[cikle[count_proxy][0]],proxies=proxies[cikle[count_proxy][1]])
                sleep(list_time_2[counter])
                print(f"ProxyError в {k}")
            
            # тело цикла
            soup_1 = BeautifulSoup(response_1.text,'lxml')
            soup_2 = BeautifulSoup(response_2.text,'lxml')
            
            title = ['id',"общая информация","Дата",'Команда1',"счет1",'Команда2',"счет2",'Температура',"Признак погоды","поб1","X","поб2","ТМ 2.5","ТБ 2.5"]
            title_Summary_statistics = ['Матчи 1','Матчи 2','Отдых: дни (часы) 1','Отдых: дни (часы) 2','Победы 1','Победы 2','Ничьи 1','Ничьи 2','Поражения 1','Поражения 2','Забито голов 1','Забито голов 2','Пропущено голов 1','Пропущено голов 2','Забито голов за игру 1','Забито голов за игру 2','Пропущено голов за игру 1','Пропущено голов за игру 2','Сухие матчи 1','Сухие матчи 2','обе забьют 1','обе забьют 2','Тотал больше 2.5 1','Тотал больше 2.5 2','Тотал меньше 2.5 1','Тотал меньше 2.5 2','Удары 1','Удары 2','Удары  (соперник) 1','Удары  (соперник) 2','Удары в створ 1','Удары в створ 2','Удары в створ  (соперник) 1','Удары в створ  (соперник) 2','Владение 1','Владение 2','Владение  (соперник) 1','Владение  (соперник) 2','Угловые 1','Угловые 2','Угловые  (соперник) 1','Угловые  (соперник) 2','Нарушения 1','Нарушения 2','Нарушения  (соперник) 1','Нарушения  (соперник) 2','Офсайды 1','Офсайды 2','Офсайды  (соперник) 1','Офсайды  (соперник) 2','Желтые карточки 1','Желтые карточки 2','Желтые карточки  (соперник) 1','Желтые карточки  (соперник) 2','Красные карточки 1','Красные карточки 2','Красные карточки  (соперник) 1','Красные карточки  (соперник) 2']
            full_title = title + title_Summary_statistics
            
            global lister
            lister = list()
            lister.append(k)
            
            #Общая инфа и время матча
            data = soup_1.find("div",class_="block_header bkcenter").text.replace("\n","")
            print(data)
            date_list = data.split()
            date_time = date_list[-2] + ' ' + date_list[-1]
            lister.append(data)
            lister.append(date_time)

            #Название команд и счет
            result_match_1= soup_1.find("div",class_="live_game left")
            result_match_2= soup_1.find("div",class_="live_game right")

            name_1_com = result_match_1.find("div",class_="live_game_ht").text.replace("\n","")
            goal_1_com = result_match_1.find("div",class_="live_game_goal").text.replace("\n","")

            name_2_com = result_match_2.find("div",class_="live_game_at").text.replace("\n","")
            goal_2_com = result_match_2.find("div",class_="live_game_goal").text.replace("\n","")
            lister.append(name_1_com)
            lister.append(goal_1_com)
            lister.append(name_2_com)
            lister.append(goal_2_com)


            #Погода
            preview_st = soup_1.find("div",class_="preview_item st")
            temper = preview_st.find("span",class_="red").text

            priznac_pog = preview_st.find_all("span",class_="min_gray")[1].text
            lister.append(temper)
            lister.append(priznac_pog)


            #Коэфиценты
            coeficent_all = soup_1.find_all("div",class_="block_body_nopadding")[3]
            coficient = coeficent_all.find_all('div',class_='odds_item odds_logo')

            def cof_func(coficient):
                list_coef = list()
                for i in coficient:
                    odds_coeff = i.find_all('div',class_='odds_coeff')
                    for j in odds_coeff:
                        if j == '\n':
                            continue
                        if j == '\xa0':
                            list_coef.clear()
                            break
                        list_coef.append(float(j.text))
                    if len(list_coef) == 5:
                        return  list_coef  
                    
            coficient_result = cof_func(coficient)
            lister.extend(coficient_result)
            result_matches_to10 = soup_2.find_all("div", class_="block_body_nopadding")
            Summary_statistics = result_matches_to10[3] 
            table_tr_1 = Summary_statistics.find_all("td")
            Summary_statistics2 = result_matches_to10[4] 
            table_tr_2 = Summary_statistics2.find_all("td")
            
            def reformed_tabl_1(table):
                lens = len(table)
                col_priz = lens / 3
                lister_pr = list()
                lister_res = list()
                for i in range(0,lens):
                    if i in [1,4,7,10,13,16,19,22,25,28,31,34,37]:
                        lister_pr.append(table[i].text + "1")
                        lister_pr.append(table[i].text + "2")
                    else:
                        lister_res.append(table[i].text.replace("\xa0"," "))
                return(lister_pr,lister_res)

            test_tr1,test_res1 = reformed_tabl_1(table_tr_1)

            #display(test_tr)
            #display(test_res)

            def reformed_tabl_2(table):
                lens = len(table)
                col_priz = lens / 3
                lister_pr = list()
                lister_res = list()
                for i in range(0,lens):
                    if i in [1,4,7,10,13,16,19,22,25,28,31,34,37,40,43,46]:
                        lister_pr.append(table[i].text + "1")
                        lister_pr.append(table[i].text + "2")
                    else:
                        lister_res.append(table[i].text.replace("\xa0"," "))
                return(lister_pr,lister_res)
            test_tr2,test_res2 = reformed_tabl_2(table_tr_2)

            #display(test_tr)
            #display(test_res)
            final_test_tr = test_tr1 + test_tr2
            final_test_res = test_res1 + test_res2
            lister.extend(final_test_res)
            data_list.append(lister)
            res_df = pd.DataFrame(
                data = data_list,
                columns= full_title,
            )
        
            
                
        #if res_df.shape[0] == len(set1):
        res_df.to_csv(f'../data_auto/{liga}{i}.csv')

# %%
list_math_n10(liga="Seria_A_liga",list_data=["2019-2020"],headers=headers,proxy=proxies)
# Out:
# 2019-2020
# 380
# Серия А, 38-й тур, регулярный сезон, 02.08.2020 21:45
# Серия А, 38-й тур, регулярный сезон, 02.08.2020 21:45
# Серия А, 38-й тур, регулярный сезон, 02.08.2020 21:45
# Серия А, 38-й тур, регулярный сезон, 02.08.2020 21:45
# Серия А, 38-й тур, регулярный сезон, 02.08.2020 19:00
# Серия А, 38-й тур, регулярный сезон, 01.08.2020 21:45
# Серия А, 38-й тур, регулярный сезон, 01.08.2020 21:45
# Серия А, 38-й тур, регулярный сезон, 01.08.2020 21:45
# Серия А, 38-й тур, регулярный сезон, 01.08.2020 21:45
# 14919450
# Серия А, 38-й тур, регулярный сезон, 01.08.2020 19:00
# Серия А, 37-й тур, регулярный сезон, 29.07.2020 22:45
# Серия А, 37-й тур, регулярный сезон, 29.07.2020 22:45
# Серия А, 37-й тур, регулярный сезон, 29.07.2020 22:45
# Серия А, 37-й тур, регулярный сезон, 29.07.2020 20:30
# Серия А, 37-й тур, регулярный сезон, 29.07.2020 20:30
# Серия А, 37-й тур, регулярный сезон, 29.07.2020 20:30
# Серия А, 37-й тур, регулярный сезон, 29.07.2020 20:30
# Серия А, 37-й тур, регулярный сезон, 29.07.2020 20:30
# Серия А, 37-й тур, регулярный сезон, 28.07.2020 22:45
# 14919442
# Серия А, 37-й тур, регулярный сезон, 28.07.2020 20:30
# Серия А, 36-й тур, регулярный сезон, 26.07.2020 22:45
# Серия А, 36-й тур, регулярный сезон, 26.07.2020 20:30
# Серия А, 36-й тур, регулярный сезон, 26.07.2020 20:30
# Серия А, 36-й тур, регулярный сезон, 26.07.2020 20:30
# Серия А, 36-й тур, регулярный сезон, 26.07.2020 20:30
# Серия А, 36-й тур, регулярный сезон, 26.07.2020 18:15
# Серия А, 36-й тур, регулярный сезон, 25.07.2020 22:45
# Серия А, 36-й тур, регулярный сезон, 25.07.2020 20:30
# Серия А, 36-й тур, регулярный сезон, 25.07.2020 18:15
# 14919433
# Серия А, 36-й тур, регулярный сезон, 24.07.2020 22:45
# Серия А, 35-й тур, регулярный сезон, 23.07.2020 22:45
# Серия А, 35-й тур, регулярный сезон, 23.07.2020 20:30
# Серия А, 35-й тур, регулярный сезон, 22.07.2020 22:45
# Серия А, 35-й тур, регулярный сезон, 22.07.2020 22:45
# Серия А, 35-й тур, регулярный сезон, 22.07.2020 22:45
# Серия А, 35-й тур, регулярный сезон, 22.07.2020 22:45
# Серия А, 35-й тур, регулярный сезон, 22.07.2020 22:45
# Серия А, 35-й тур, регулярный сезон, 22.07.2020 20:30
# Серия А, 35-й тур, регулярный сезон, 21.07.2020 22:45
# 14919418
# Серия А, 35-й тур, регулярный сезон, 21.07.2020 20:30
# Серия А, 34-й тур, регулярный сезон, 20.07.2020 22:45
# Серия А, 34-й тур, регулярный сезон, 19.07.2020 22:45
# Серия А, 34-й тур, регулярный сезон, 19.07.2020 20:30
# Серия А, 34-й тур, регулярный сезон, 19.07.2020 20:30
# Серия А, 34-й тур, регулярный сезон, 19.07.2020 20:30
# Серия А, 34-й тур, регулярный сезон, 19.07.2020 20:30
# Серия А, 34-й тур, регулярный сезон, 19.07.2020 18:15
# Серия А, 34-й тур, регулярный сезон, 18.07.2020 22:45
# Серия А, 34-й тур, регулярный сезон, 18.07.2020 20:30
# 14919417
# Серия А, 34-й тур, регулярный сезон, 18.07.2020 18:15
# Серия А, 33-й тур, регулярный сезон, 16.07.2020 22:45
# Серия А, 33-й тур, регулярный сезон, 16.07.2020 20:30
# Серия А, 33-й тур, регулярный сезон, 15.07.2020 22:45
# Серия А, 33-й тур, регулярный сезон, 15.07.2020 22:45
# Серия А, 33-й тур, регулярный сезон, 15.07.2020 22:45
# Серия А, 33-й тур, регулярный сезон, 15.07.2020 22:45
# Серия А, 33-й тур, регулярный сезон, 15.07.2020 20:30
# Серия А, 33-й тур, регулярный сезон, 15.07.2020 20:30
# Серия А, 33-й тур, регулярный сезон, 15.07.2020 20:30
# 14919398
# Серия А, 33-й тур, регулярный сезон, 14.07.2020 22:45
# Серия А, 32-й тур, регулярный сезон, 13.07.2020 22:45
# Серия А, 32-й тур, регулярный сезон, 12.07.2020 22:45
# Серия А, 32-й тур, регулярный сезон, 12.07.2020 20:30
# Серия А, 32-й тур, регулярный сезон, 12.07.2020 20:30
# Серия А, 32-й тур, регулярный сезон, 12.07.2020 20:30
# Серия А, 32-й тур, регулярный сезон, 12.07.2020 20:30
# Серия А, 32-й тур, регулярный сезон, 12.07.2020 18:15
# Серия А, 32-й тур, регулярный сезон, 11.07.2020 22:45
# Серия А, 32-й тур, регулярный сезон, 11.07.2020 20:30
# 14919394
# Серия А, 32-й тур, регулярный сезон, 11.07.2020 18:15
# Серия А, 31-й тур, регулярный сезон, 09.07.2020 22:45
# Серия А, 31-й тур, регулярный сезон, 09.07.2020 20:30
# Серия А, 31-й тур, регулярный сезон, 08.07.2020 22:45
# Серия А, 31-й тур, регулярный сезон, 08.07.2020 22:45
# Серия А, 31-й тур, регулярный сезон, 08.07.2020 22:45
# Серия А, 31-й тур, регулярный сезон, 08.07.2020 22:45
# Серия А, 31-й тур, регулярный сезон, 08.07.2020 20:30
# Серия А, 31-й тур, регулярный сезон, 08.07.2020 20:30
# Серия А, 31-й тур, регулярный сезон, 07.07.2020 22:50
# 14919382
# Серия А, 31-й тур, регулярный сезон, 07.07.2020 20:30
# Серия А, 30-й тур, регулярный сезон, 05.07.2020 22:45
# Серия А, 30-й тур, регулярный сезон, 05.07.2020 20:30
# Серия А, 30-й тур, регулярный сезон, 05.07.2020 20:30
# Серия А, 30-й тур, регулярный сезон, 05.07.2020 20:30
# Серия А, 30-й тур, регулярный сезон, 05.07.2020 20:30
# Серия А, 30-й тур, регулярный сезон, 05.07.2020 20:30
# Серия А, 30-й тур, регулярный сезон, 05.07.2020 18:15
# Серия А, 30-й тур, регулярный сезон, 04.07.2020 22:45
# Серия А, 30-й тур, регулярный сезон, 04.07.2020 20:30
# 14919371
# Серия А, 30-й тур, регулярный сезон, 04.07.2020 18:15
# Серия А, 29-й тур, регулярный сезон, 02.07.2020 22:45
# Серия А, 29-й тур, регулярный сезон, 02.07.2020 20:30
# Серия А, 29-й тур, регулярный сезон, 01.07.2020 22:45
# Серия А, 29-й тур, регулярный сезон, 01.07.2020 22:45
# Серия А, 29-й тур, регулярный сезон, 01.07.2020 22:45
# Серия А, 29-й тур, регулярный сезон, 01.07.2020 22:45
# Серия А, 29-й тур, регулярный сезон, 01.07.2020 20:30
# Серия А, 29-й тур, регулярный сезон, 01.07.2020 20:30
# Серия А, 29-й тур, регулярный сезон, 30.06.2020 22:45
# 14919366
# Серия А, 29-й тур, регулярный сезон, 30.06.2020 20:30
# Серия А, 28-й тур, регулярный сезон, 28.06.2020 22:45
# Серия А, 28-й тур, регулярный сезон, 28.06.2020 20:35
# Серия А, 28-й тур, регулярный сезон, 28.06.2020 20:30
# Серия А, 28-й тур, регулярный сезон, 28.06.2020 20:30
# Серия А, 28-й тур, регулярный сезон, 28.06.2020 20:30
# Серия А, 28-й тур, регулярный сезон, 28.06.2020 18:15
# Серия А, 28-й тур, регулярный сезон, 27.06.2020 22:45
# Серия А, 28-й тур, регулярный сезон, 27.06.2020 20:30
# Серия А, 28-й тур, регулярный сезон, 27.06.2020 18:15
# 14919350
# Серия А, 28-й тур, регулярный сезон, 26.06.2020 22:45
# Серия А, 27-й тур, регулярный сезон, 24.06.2020 22:45
# Серия А, 27-й тур, регулярный сезон, 24.06.2020 22:45
# Серия А, 27-й тур, регулярный сезон, 24.06.2020 20:30
# Серия А, 27-й тур, регулярный сезон, 23.06.2020 22:45
# Серия А, 27-й тур, регулярный сезон, 23.06.2020 22:45
# Серия А, 27-й тур, регулярный сезон, 23.06.2020 20:30
# Серия А, 27-й тур, регулярный сезон, 23.06.2020 20:30
# Серия А, 27-й тур, регулярный сезон, 22.06.2020 22:45
# Серия А, 27-й тур, регулярный сезон, 22.06.2020 20:30
# 14919343
# Серия А, 27-й тур, регулярный сезон, 22.06.2020 20:30
# Серия А, 25-й тур, регулярный сезон, 21.06.2020 22:45
# Серия А, 25-й тур, регулярный сезон, 21.06.2020 20:30
# Серия А, 25-й тур, регулярный сезон, 20.06.2020 22:45
# Серия А, 25-й тур, регулярный сезон, 20.06.2020 20:30
# Серия А, 26-й тур, регулярный сезон, 09.03.2020 19:30
# Серия А, 26-й тур, регулярный сезон, 08.03.2020 21:45
# Серия А, 26-й тур, регулярный сезон, 08.03.2020 19:00
# Серия А, 26-й тур, регулярный сезон, 08.03.2020 16:00
# Серия А, 26-й тур, регулярный сезон, 08.03.2020 16:00
# 14919334
# Серия А, 26-й тур, регулярный сезон, 08.03.2020 14:45
# Серия А, 26-й тур, регулярный сезон, 01.03.2020 19:00
# Серия А, 26-й тур, регулярный сезон, 01.03.2020 16:00
# Серия А, 26-й тур, регулярный сезон, 29.02.2020 21:45
# Серия А, 26-й тур, регулярный сезон, 29.02.2020 16:00
# Серия А, 25-й тур, регулярный сезон, 23.02.2020 19:00
# Серия А, 25-й тур, регулярный сезон, 23.02.2020 13:30
# Серия А, 25-й тур, регулярный сезон, 22.02.2020 21:45
# Серия А, 25-й тур, регулярный сезон, 22.02.2020 19:00
# Серия А, 25-й тур, регулярный сезон, 22.02.2020 16:00
# 14919320
# Серия А, 25-й тур, регулярный сезон, 21.02.2020 21:45
# Серия А, 24-й тур, регулярный сезон, 17.02.2020 21:45
# Серия А, 24-й тур, регулярный сезон, 16.02.2020 21:45
# Серия А, 24-й тур, регулярный сезон, 16.02.2020 19:00
# Серия А, 24-й тур, регулярный сезон, 16.02.2020 16:00
# Серия А, 24-й тур, регулярный сезон, 16.02.2020 16:00
# Серия А, 24-й тур, регулярный сезон, 16.02.2020 16:00
# Серия А, 24-й тур, регулярный сезон, 16.02.2020 13:30
# Серия А, 24-й тур, регулярный сезон, 15.02.2020 21:45
# Серия А, 24-й тур, регулярный сезон, 15.02.2020 19:00
# 14919313
# Серия А, 24-й тур, регулярный сезон, 15.02.2020 16:00
# Серия А, 23-й тур, регулярный сезон, 09.02.2020 21:45
# Серия А, 23-й тур, регулярный сезон, 09.02.2020 19:00
# Серия А, 23-й тур, регулярный сезон, 09.02.2020 16:00
# Серия А, 23-й тур, регулярный сезон, 09.02.2020 16:00
# Серия А, 23-й тур, регулярный сезон, 09.02.2020 16:00
# Серия А, 23-й тур, регулярный сезон, 09.02.2020 13:30
# Серия А, 23-й тур, регулярный сезон, 08.02.2020 21:45
# Серия А, 23-й тур, регулярный сезон, 08.02.2020 19:00
# Серия А, 23-й тур, регулярный сезон, 08.02.2020 16:00
# 14919304
# Серия А, 23-й тур, регулярный сезон, 07.02.2020 21:45
# Серия А, 17-й тур, регулярный сезон, 05.02.2020 21:45
# Серия А, 22-й тур, регулярный сезон, 03.02.2020 21:45
# Серия А, 22-й тур, регулярный сезон, 02.02.2020 21:45
# Серия А, 22-й тур, регулярный сезон, 02.02.2020 19:00
# Серия А, 22-й тур, регулярный сезон, 02.02.2020 16:00
# Серия А, 22-й тур, регулярный сезон, 02.02.2020 16:00
# Серия А, 22-й тур, регулярный сезон, 02.02.2020 16:00
# Серия А, 22-й тур, регулярный сезон, 02.02.2020 13:30
# Серия А, 22-й тур, регулярный сезон, 01.02.2020 21:45
# 14919290
# Серия А, 22-й тур, регулярный сезон, 01.02.2020 19:00
# Серия А, 22-й тур, регулярный сезон, 01.02.2020 16:05
# Серия А, 21-й тур, регулярный сезон, 26.01.2020 21:45
# Серия А, 21-й тур, регулярный сезон, 26.01.2020 19:00
# Серия А, 21-й тур, регулярный сезон, 26.01.2020 16:00
# Серия А, 21-й тур, регулярный сезон, 26.01.2020 16:00
# Серия А, 21-й тур, регулярный сезон, 26.01.2020 16:00
# Серия А, 21-й тур, регулярный сезон, 26.01.2020 13:30
# Серия А, 21-й тур, регулярный сезон, 25.01.2020 21:50
# Серия А, 21-й тур, регулярный сезон, 25.01.2020 19:00
# 14919285
# Серия А, 21-й тур, регулярный сезон, 25.01.2020 16:00
# Серия А, 21-й тур, регулярный сезон, 24.01.2020 21:45
# Серия А, 20-й тур, регулярный сезон, 20.01.2020 21:45
# Серия А, 20-й тур, регулярный сезон, 19.01.2020 21:45
# Серия А, 20-й тур, регулярный сезон, 19.01.2020 19:00
# Серия А, 20-й тур, регулярный сезон, 19.01.2020 16:00
# Серия А, 20-й тур, регулярный сезон, 19.01.2020 16:00
# Серия А, 20-й тур, регулярный сезон, 19.01.2020 16:00
# Серия А, 20-й тур, регулярный сезон, 19.01.2020 13:35
# Серия А, 20-й тур, регулярный сезон, 18.01.2020 21:45
# 14919277
# Серия А, 20-й тур, регулярный сезон, 18.01.2020 19:00
# Серия А, 20-й тур, регулярный сезон, 18.01.2020 16:00
# Серия А, 19-й тур, регулярный сезон, 13.01.2020 21:45
# Серия А, 19-й тур, регулярный сезон, 12.01.2020 21:45
# Серия А, 19-й тур, регулярный сезон, 12.01.2020 19:15
# Серия А, 19-й тур, регулярный сезон, 12.01.2020 16:00
# Серия А, 19-й тур, регулярный сезон, 12.01.2020 16:00
# Серия А, 19-й тур, регулярный сезон, 12.01.2020 16:00
# Серия А, 19-й тур, регулярный сезон, 12.01.2020 13:30
# Серия А, 19-й тур, регулярный сезон, 11.01.2020 21:45
# 14919262
# Серия А, 19-й тур, регулярный сезон, 11.01.2020 19:00
# Серия А, 19-й тур, регулярный сезон, 11.01.2020 16:00
# Серия А, 18-й тур, регулярный сезон, 06.01.2020 21:45
# Серия А, 18-й тур, регулярный сезон, 06.01.2020 19:00
# Серия А, 18-й тур, регулярный сезон, 06.01.2020 16:00
# Серия А, 18-й тур, регулярный сезон, 06.01.2020 16:00
# Серия А, 18-й тур, регулярный сезон, 06.01.2020 16:00
# Серия А, 18-й тур, регулярный сезон, 06.01.2020 13:30
# Серия А, 18-й тур, регулярный сезон, 05.01.2020 21:45
# Серия А, 18-й тур, регулярный сезон, 05.01.2020 19:00
# 14919257
# Серия А, 18-й тур, регулярный сезон, 05.01.2020 16:00
# Серия А, 18-й тур, регулярный сезон, 05.01.2020 13:30
# Серия А, 17-й тур, регулярный сезон, 22.12.2019 21:45
# Серия А, 17-й тур, регулярный сезон, 22.12.2019 16:00
# Серия А, 17-й тур, регулярный сезон, 22.12.2019 16:00
# Серия А, 17-й тур, регулярный сезон, 22.12.2019 13:30
# Серия А, 17-й тур, регулярный сезон, 21.12.2019 21:45
# Серия А, 17-й тур, регулярный сезон, 21.12.2019 19:00
# Серия А, 17-й тур, регулярный сезон, 21.12.2019 16:00
# Серия А, 17-й тур, регулярный сезон, 20.12.2019 21:45
# 14919140
# Серия А, 7-й тур, регулярный сезон, 18.12.2019 21:45
# Серия А, 17-й тур, регулярный сезон, 18.12.2019 19:55
# Серия А, 16-й тур, регулярный сезон, 16.12.2019 21:45
# Серия А, 16-й тур, регулярный сезон, 15.12.2019 21:45
# Серия А, 16-й тур, регулярный сезон, 15.12.2019 19:00
# Серия А, 16-й тур, регулярный сезон, 15.12.2019 16:00
# Серия А, 16-й тур, регулярный сезон, 15.12.2019 16:00
# Серия А, 16-й тур, регулярный сезон, 15.12.2019 16:00
# Серия А, 16-й тур, регулярный сезон, 15.12.2019 13:30
# Серия А, 16-й тур, регулярный сезон, 14.12.2019 21:45
# 14919236
# Серия А, 16-й тур, регулярный сезон, 14.12.2019 19:30
# Серия А, 16-й тур, регулярный сезон, 14.12.2019 16:00
# Серия А, 15-й тур, регулярный сезон, 08.12.2019 21:45
# Серия А, 15-й тур, регулярный сезон, 08.12.2019 19:00
# Серия А, 15-й тур, регулярный сезон, 08.12.2019 16:00
# Серия А, 15-й тур, регулярный сезон, 08.12.2019 16:00
# Серия А, 15-й тур, регулярный сезон, 08.12.2019 16:00
# Серия А, 15-й тур, регулярный сезон, 08.12.2019 13:30
# Серия А, 15-й тур, регулярный сезон, 07.12.2019 21:45
# Серия А, 15-й тур, регулярный сезон, 07.12.2019 19:00
# 14919218
# Серия А, 15-й тур, регулярный сезон, 07.12.2019 16:00
# Серия А, 15-й тур, регулярный сезон, 06.12.2019 21:50
# Серия А, 14-й тур, регулярный сезон, 02.12.2019 21:45
# Серия А, 14-й тур, регулярный сезон, 01.12.2019 21:45
# Серия А, 14-й тур, регулярный сезон, 01.12.2019 19:00
# Серия А, 14-й тур, регулярный сезон, 01.12.2019 16:00
# Серия А, 14-й тур, регулярный сезон, 01.12.2019 16:00
# Серия А, 14-й тур, регулярный сезон, 01.12.2019 16:00
# Серия А, 14-й тур, регулярный сезон, 01.12.2019 13:30
# Серия А, 14-й тур, регулярный сезон, 30.11.2019 21:45
# 14919211
# Серия А, 14-й тур, регулярный сезон, 30.11.2019 19:00
# Серия А, 14-й тур, регулярный сезон, 30.11.2019 16:00
# Серия А, 13-й тур, регулярный сезон, 25.11.2019 21:45
# Серия А, 13-й тур, регулярный сезон, 25.11.2019 16:00
# Серия А, 13-й тур, регулярный сезон, 24.11.2019 19:00
# Серия А, 13-й тур, регулярный сезон, 24.11.2019 16:00
# Серия А, 13-й тур, регулярный сезон, 24.11.2019 16:00
# Серия А, 13-й тур, регулярный сезон, 24.11.2019 16:00
# Серия А, 13-й тур, регулярный сезон, 24.11.2019 13:30
# Серия А, 13-й тур, регулярный сезон, 23.11.2019 21:55
# 14919202
# Серия А, 13-й тур, регулярный сезон, 23.11.2019 19:00
# Серия А, 13-й тур, регулярный сезон, 23.11.2019 16:00
# Серия А, 12-й тур, регулярный сезон, 10.11.2019 21:45
# Серия А, 12-й тур, регулярный сезон, 10.11.2019 19:00
# Серия А, 12-й тур, регулярный сезон, 10.11.2019 16:00
# Серия А, 12-й тур, регулярный сезон, 10.11.2019 16:00
# Серия А, 12-й тур, регулярный сезон, 10.11.2019 16:00
# Серия А, 12-й тур, регулярный сезон, 10.11.2019 13:30
# Серия А, 12-й тур, регулярный сезон, 09.11.2019 21:45
# Серия А, 12-й тур, регулярный сезон, 09.11.2019 19:00
# 14919188
# Серия А, 12-й тур, регулярный сезон, 09.11.2019 16:00
# Серия А, 12-й тур, регулярный сезон, 08.11.2019 21:45
# Серия А, 11-й тур, регулярный сезон, 04.11.2019 21:45
# Серия А, 11-й тур, регулярный сезон, 03.11.2019 21:45
# Серия А, 11-й тур, регулярный сезон, 03.11.2019 19:00
# Серия А, 11-й тур, регулярный сезон, 03.11.2019 16:00
# Серия А, 11-й тур, регулярный сезон, 03.11.2019 16:00
# Серия А, 11-й тур, регулярный сезон, 03.11.2019 16:00
# Серия А, 11-й тур, регулярный сезон, 03.11.2019 13:30
# Серия А, 11-й тур, регулярный сезон, 02.11.2019 21:45
# 14919179
# Серия А, 11-й тур, регулярный сезон, 02.11.2019 19:00
# Серия А, 11-й тур, регулярный сезон, 02.11.2019 16:00
# Серия А, 10-й тур, регулярный сезон, 31.10.2019 22:00
# Серия А, 10-й тур, регулярный сезон, 30.10.2019 22:00
# Серия А, 10-й тур, регулярный сезон, 30.10.2019 22:00
# Серия А, 10-й тур, регулярный сезон, 30.10.2019 22:00
# Серия А, 10-й тур, регулярный сезон, 30.10.2019 22:00
# Серия А, 10-й тур, регулярный сезон, 30.10.2019 22:00
# Серия А, 10-й тур, регулярный сезон, 30.10.2019 22:00
# Серия А, 10-й тур, регулярный сезон, 30.10.2019 20:00
# 14919168
# Серия А, 10-й тур, регулярный сезон, 29.10.2019 22:00
# Серия А, 10-й тур, регулярный сезон, 29.10.2019 20:00
# Серия А, 9-й тур, регулярный сезон, 27.10.2019 21:45
# Серия А, 9-й тур, регулярный сезон, 27.10.2019 19:00
# Серия А, 9-й тур, регулярный сезон, 27.10.2019 16:00
# Серия А, 9-й тур, регулярный сезон, 27.10.2019 16:00
# Серия А, 9-й тур, регулярный сезон, 27.10.2019 16:00
# Серия А, 9-й тур, регулярный сезон, 27.10.2019 13:30
# Серия А, 9-й тур, регулярный сезон, 26.10.2019 21:45
# Серия А, 9-й тур, регулярный сезон, 26.10.2019 19:00
# 14919164
# Серия А, 9-й тур, регулярный сезон, 26.10.2019 16:00
# Серия А, 9-й тур, регулярный сезон, 25.10.2019 21:45
# Серия А, 8-й тур, регулярный сезон, 21.10.2019 22:00
# Серия А, 8-й тур, регулярный сезон, 20.10.2019 21:45
# Серия А, 8-й тур, регулярный сезон, 20.10.2019 19:00
# Серия А, 8-й тур, регулярный сезон, 20.10.2019 16:00
# Серия А, 8-й тур, регулярный сезон, 20.10.2019 16:00
# Серия А, 8-й тур, регулярный сезон, 20.10.2019 16:00
# Серия А, 8-й тур, регулярный сезон, 20.10.2019 13:30
# Серия А, 8-й тур, регулярный сезон, 19.10.2019 21:45
# 14919153
# Серия А, 8-й тур, регулярный сезон, 19.10.2019 19:00
# Серия А, 8-й тур, регулярный сезон, 19.10.2019 16:00
# Серия А, 7-й тур, регулярный сезон, 06.10.2019 21:45
# Серия А, 7-й тур, регулярный сезон, 06.10.2019 19:00
# Серия А, 7-й тур, регулярный сезон, 06.10.2019 16:00
# Серия А, 7-й тур, регулярный сезон, 06.10.2019 16:00
# Серия А, 7-й тур, регулярный сезон, 06.10.2019 16:00
# Серия А, 7-й тур, регулярный сезон, 06.10.2019 13:30
# Серия А, 7-й тур, регулярный сезон, 05.10.2019 21:45
# Серия А, 7-й тур, регулярный сезон, 05.10.2019 19:00
# 14919146
# Серия А, 7-й тур, регулярный сезон, 05.10.2019 16:00
# Серия А, 6-й тур, регулярный сезон, 30.09.2019 21:45
# Серия А, 6-й тур, регулярный сезон, 29.09.2019 21:45
# Серия А, 6-й тур, регулярный сезон, 29.09.2019 19:00
# Серия А, 6-й тур, регулярный сезон, 29.09.2019 16:00
# Серия А, 6-й тур, регулярный сезон, 29.09.2019 16:00
# Серия А, 6-й тур, регулярный сезон, 29.09.2019 16:00
# Серия А, 6-й тур, регулярный сезон, 29.09.2019 13:30
# Серия А, 6-й тур, регулярный сезон, 28.09.2019 21:45
# Серия А, 6-й тур, регулярный сезон, 28.09.2019 19:00
# 14919129
# Серия А, 6-й тур, регулярный сезон, 28.09.2019 16:00
# Серия А, 5-й тур, регулярный сезон, 26.09.2019 22:00
# Серия А, 5-й тур, регулярный сезон, 25.09.2019 22:00
# Серия А, 5-й тур, регулярный сезон, 25.09.2019 22:00
# Серия А, 5-й тур, регулярный сезон, 25.09.2019 22:00
# Серия А, 5-й тур, регулярный сезон, 25.09.2019 22:00
# Серия А, 5-й тур, регулярный сезон, 25.09.2019 22:00
# Серия А, 5-й тур, регулярный сезон, 25.09.2019 22:00
# Серия А, 5-й тур, регулярный сезон, 25.09.2019 20:00
# Серия А, 5-й тур, регулярный сезон, 24.09.2019 22:00
# 14919121
# Серия А, 5-й тур, регулярный сезон, 24.09.2019 20:00
# Серия А, 4-й тур, регулярный сезон, 22.09.2019 21:45
# Серия А, 4-й тур, регулярный сезон, 22.09.2019 19:00
# Серия А, 4-й тур, регулярный сезон, 22.09.2019 16:00
# Серия А, 4-й тур, регулярный сезон, 22.09.2019 16:00
# Серия А, 4-й тур, регулярный сезон, 22.09.2019 16:00
# Серия А, 4-й тур, регулярный сезон, 22.09.2019 13:30
# Серия А, 4-й тур, регулярный сезон, 21.09.2019 21:45
# Серия А, 4-й тур, регулярный сезон, 21.09.2019 19:00
# Серия А, 4-й тур, регулярный сезон, 21.09.2019 16:00
# 14919110
# Серия А, 4-й тур, регулярный сезон, 20.09.2019 21:45
# Серия А, 3-й тур, регулярный сезон, 16.09.2019 21:45
# Серия А, 3-й тур, регулярный сезон, 15.09.2019 21:45
# Серия А, 3-й тур, регулярный сезон, 15.09.2019 19:00
# Серия А, 3-й тур, регулярный сезон, 15.09.2019 16:00
# Серия А, 3-й тур, регулярный сезон, 15.09.2019 16:00
# Серия А, 3-й тур, регулярный сезон, 15.09.2019 16:00
# Серия А, 3-й тур, регулярный сезон, 15.09.2019 13:30
# Серия А, 3-й тур, регулярный сезон, 14.09.2019 21:45
# Серия А, 3-й тур, регулярный сезон, 14.09.2019 19:00
# 14919099
# Серия А, 3-й тур, регулярный сезон, 14.09.2019 16:00
# Серия А, 2-й тур, регулярный сезон, 01.09.2019 21:45
# Серия А, 2-й тур, регулярный сезон, 01.09.2019 21:45
# Серия А, 2-й тур, регулярный сезон, 01.09.2019 21:45
# Серия А, 2-й тур, регулярный сезон, 01.09.2019 21:45
# Серия А, 2-й тур, регулярный сезон, 01.09.2019 21:45
# Серия А, 2-й тур, регулярный сезон, 01.09.2019 21:45
# Серия А, 2-й тур, регулярный сезон, 01.09.2019 19:00
# Серия А, 2-й тур, регулярный сезон, 31.08.2019 21:45
# Серия А, 2-й тур, регулярный сезон, 31.08.2019 19:00
# 14919089
# Серия А, 2-й тур, регулярный сезон, 30.08.2019 21:45
# Серия А, 1-й тур, регулярный сезон, 26.08.2019 21:45
# Серия А, 1-й тур, регулярный сезон, 25.08.2019 21:45
# Серия А, 1-й тур, регулярный сезон, 25.08.2019 21:45
# Серия А, 1-й тур, регулярный сезон, 25.08.2019 21:45
# Серия А, 1-й тур, регулярный сезон, 25.08.2019 21:45
# Серия А, 1-й тур, регулярный сезон, 25.08.2019 21:45
# Серия А, 1-й тур, регулярный сезон, 25.08.2019 21:45
# Серия А, 1-й тур, регулярный сезон, 25.08.2019 19:00
# Серия А, 1-й тур, регулярный сезон, 24.08.2019 21:45
# 14919082
# Серия А, 1-й тур, регулярный сезон, 24.08.2019 19:00
#            id                                   общая информация  \
# 0    14919449  Серия А, 38-й тур, регулярный сезон, 02.08.202...
# 1    14919451  Серия А, 38-й тур, регулярный сезон, 02.08.202...
# 2    14919453  Серия А, 38-й тур, регулярный сезон, 02.08.202...
# 3    14919456  Серия А, 38-й тур, регулярный сезон, 02.08.202...
# 4    14919457  Серия А, 38-й тур, регулярный сезон, 02.08.202...
# ..        ...                                                ...
# 375  14919085  Серия А, 1-й тур, регулярный сезон, 25.08.2019...
# 376  14919086  Серия А, 1-й тур, регулярный сезон, 25.08.2019...
# 377  14919087  Серия А, 1-й тур, регулярный сезон, 25.08.2019...
# 378  14919079  Серия А, 1-й тур, регулярный сезон, 24.08.2019...
# 379  14919082  Серия А, 1-й тур, регулярный сезон, 24.08.2019...
#
#                  Дата    Команда1 счет1    Команда2 счет2 Температура  \
# 0    02.08.2020 21:45     Болонья     1      Торино     1       +19°C
# 1    02.08.2020 21:45      Дженоа     3      Верона     0       +20°C
# 2    02.08.2020 21:45       Лечче     3       Парма     4       +20°C
# 3    02.08.2020 21:45    Сассуоло     0     Удинезе     1       +13°C
# 4    02.08.2020 19:00        СПАЛ     1  Фиорентина     3       +19°C
# ..                ...         ...   ...         ...   ...         ...
# 375  25.08.2019 21:45        СПАЛ     2    Аталанта     3       +19°C
# 376  25.08.2019 21:45      Торино     2    Сассуоло     1       +11°C
# 377  25.08.2019 19:00     Удинезе     1       Милан     0       +16°C
# 378  24.08.2019 21:45  Фиорентина     3      Наполи     4       +16°C
# 379  24.08.2019 19:00       Парма     0     Ювентус     1       +14°C
#
#             Признак погоды  поб1  ...  Офсайды  (соперник) 1  \
# 0    переменная облачность  1.88  ...                   1.00
# 1    переменная облачность  1.70  ...                   1.50
# 2    переменная облачность  1.59  ...                   2.10
# 3                    туман  1.89  ...                   1.80
# 4    переменная облачность  7.90  ...                   1.50
# ..                     ...   ...  ...                    ...
# 375  переменная облачность  5.35  ...                   2.00
# 376                   ясно  1.90  ...                   0.88
# 377  переменная облачность  3.96  ...                   0.60
# 378  переменная облачность  4.33  ...                   1.00
# 379                  дымка  8.70  ...                   0.83
#
#      Офсайды  (соперник) 2  Желтые карточки 1  Желтые карточки 2  \
# 0                     1.80               1.70               2.00
# 1                     0.80               2.00               2.00
# 2                     1.80               2.30               1.90
# 3                     0.70               2.50               1.60
# 4                     2.80               1.70               2.90
# ..                     ...                ...                ...
# 375                   2.00               1.33               1.00
# 376                   1.80               1.56               2.60
# 377                   1.75               1.71               1.67
# 378                   2.20               2.33               1.20
# 379                   1.11               1.88               1.30
#
#     Желтые карточки  (соперник) 1 Желтые карточки  (соперник) 2  \
# 0                            2.20                          2.80
# 1                            2.30                          2.60
# 2                            1.80                          2.60
# 3                            3.00                          2.50
# 4                            1.10                          2.30
# ..                            ...                           ...
# 375                          1.17                          1.67
# 376                          1.56                          2.80
# 377                          2.00                          1.67
# 378                          2.17                          1.00
# 379                          1.25                          1.30
#
#     Красные карточки 1 Красные карточки 2 Красные карточки  (соперник) 1  \
# 0                 0.10                  0                           0.10
# 1                    0                  0                              0
# 2                 0.10               0.10                           0.10
# 3                 0.10                  0                           0.10
# 4                 0.20               0.10                              0
# ..                 ...                ...                            ...
# 375                  0                  0                           0.17
# 376                  0               0.60                           0.11
# 377                  0               0.22                              0
# 378                  0                  0                              0
# 379               0.25               0.10                           0.13
#
#     Красные карточки  (соперник) 2
# 0                                0
# 1                                0
# 2                             0.10
# 3                             0.10
# 4                                0
# ..                             ...
# 375                           0.33
# 376                           0.20
# 377                           0.22
# 378                              0
# 379                              0
#
# [380 rows x 72 columns]
